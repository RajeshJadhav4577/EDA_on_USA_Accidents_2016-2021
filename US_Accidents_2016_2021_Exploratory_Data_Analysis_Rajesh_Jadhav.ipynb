# %% [markdown]
# # **US Accidents 2016 - 2021 Exploratory Data Analysis**
#
# **Dataset Source**: Kaggle
#
# **Dataset_Name**: US_car_accidents_2016-2021
#
# **Source_link**: https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents
#
#
# **Description:**
# This dataset contains the number of accidents occured in 49 states of the US.
# This dataset has been collected in real-time, using multiple Traffic APIs from February 2016 to Dec 2021, that provide streaming traffic incident (or event) data. These APIs broadcast traffic data captured by a variety of entities, such as the US and state departments of transportation, law enforcement agencies, traffic cameras, and traffic sensors within the road-networks. Currently, there are about 2.8 million accident records in this dataset.

# %% [markdown]
# ###**Dataset abbrevations:**<br>
# 1-ID - This is a unique identifier of the accident record.
#
# 2-Severity - Shows the severity of the accident, a number between 1 and 4, where 1 indicates the least impact on traffic (i.e., short delay as a result of the accident) and 4 indicates a significant impact on traffic (i.e., long delay).
#
# 3-Start_Time - Shows start time of the accident in local time zone.
#
# 4-End_Time - Shows end time of the accident in local time zone. End time here refers to when the impact of accident on traffic flow
#
# 5-Start_Lat - Shows latitude in GPS coordinate of the start point.
#
# 6-Start_Lng - Shows longitude in GPS coordinate of the start point.
#
# 7-End_Lat - Shows latitude in GPS coordinate of the end point.
#
# 8-End_Lng - Shows longitude in GPS coordinate of the end point.
#
# 9-Distance(mi) - The length of the road extent affected by the accident.
#
# 10-Description - Shows natural language description of the accident.
#
# 11-Number - Shows the street number in address record.
#
# 12-Street - Shows the street name in address record.
#
# 13-Side - Shows the relative side of the street (Right/Left) in address record.
#
# 14-City - Shows the city in address record.
#
# 15-County - Shows the county in address record.
#
# 16-State - Shows the state in address record.
#
# 17-Zipcode - Shows the zipcode in address record.
#
# 18-Country - Shows the country in address record.
#
# 19-Timezone - Shows timezone based on the location of the accident (eastern, central, etc.).
#
# 20-Airport_Code - Denotes an airport-based weather station which is the closest one to location of the accident.
#
# 21-Weather_Timestamp - Shows the time-stamp of weather observation record (in local time).
#
# 22-Temperature(F) - Shows the temperature (in Fahrenheit).
#
# 23-Wind_Chill(F) - Shows the wind chill (in Fahrenheit).
#
# 24-Humidity(%) - Shows the humidity (in percentage).
#
# 25-Pressure(in) - Shows the air pressure (in inches).
#
# 26-Visibility(mi) - Shows visibility (in miles).
#
# 27-Wind_Direction - Shows wind direction.
#
# 28-Wind_Speed(mph) - Shows wind speed (in miles per hour).
#
# 29-Precipitation(in) - Shows precipitation amount in inches, if there is any.
#
# 30-Weather_Condition - Shows the weather condition (rain, snow, thunderstorm, fog, etc.)
#
# 31-Amenity - A POI annotation which indicates presence of amenity in a nearby location.
#
# 32-Bump - A POI annotation which indicates presence of speed bump or hump in a nearby location.
#
# 33-Crossing - A POI annotation which indicates presence of crossing in a nearby location.
#
# 34-Give_Way - A POI annotation which indicates presence of give_way in a nearby location.
#
# 35-Junction - A POI annotation which indicates presence of junction in a nearby location.
#
# 36-No_Exit - A POI annotation which indicates presence of junction in a nearby location.
#
# 37-Railway - A POI annotation which indicates presence of railway in a nearby location.
#
# 38-Roundabout - A POI annotation which indicates presence of roundabout in a nearby location.
#
# 39-Station - A POI annotation which indicates presence of station in a nearby location.
#
# 40-Stop - A POI annotation which indicates presence of stop in a nearby location.
#
# 41-Traffic_Calming - A POI annotation which indicates presence of traffic_calming in a nearby location.
#
# 42-Traffic_Signal - A POI annotation which indicates presence of traffic_signal in a nearby location.
#
# 43-Turning_Loop - A POI annotation which indicates presence of turning_loop in a nearby location.
#
# 44-Sunrise_Sunset - Shows the period of day (i.e. day or night) based on sunrise/sunset.
#
# 45-Civil_Twilight - Shows the period of day (i.e. day or night) based on civil twilight.
#
# 46-Nautical_Twilight - Shows the period of day (i.e. day or night) based on nautical twilight.

# %% [markdown]
# ## Data Preparation and Cleaning<br>
# * Load the file using Pandas<br>
# * Look at some information about the data & the columns
# * Fix any missing or incorrect values

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing the required libraries 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")


import warnings
warnings.filterwarnings("ignore")

# %%
# Reading the data using Pandas
df_raw = pd.read_csv("/content/drive/MyDrive/Data For EDA/US_Accidents_Dec21_updated.csv")

# %%
# To know Number of rows and columns
df_raw.shape
# Out:
# (2845342, 47)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df_raw.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711439e+01
# std    4.787216e-01  5.363797e+00  1.831782e+01  5.363873e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609799e+01 -9.241772e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845342e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026779e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# ...

# %%
# To check number of numerical columns
numeric_data = df_raw.select_dtypes(include= [np.number])

# %%
len(numeric_data)
# Out:
# 2845342

# %%
# To know percentage of missing values in each column
df_raw_missing_percentage = df_raw.isnull().sum().sort_values(ascending = False)/ len(df_raw)*100

# %%
df_raw_missing_percentage
# Out:
# Number                   61.290031
# Precipitation(in)        19.310789
# Wind_Chill(F)            16.505678
# Wind_Speed(mph)           5.550967
# Wind_Direction            2.592834
# Humidity(%)               2.568830
# Weather_Condition         2.482514
# Visibility(mi)            2.479350
# Temperature(F)            2.434646
# Pressure(in)              2.080593
# Weather_Timestamp         1.783125
# Airport_Code              0.335601
# Timezone                  0.128596
# Nautical_Twilight         0.100761
# Civil_Twilight            0.100761
# Sunrise_Sunset            0.100761
# Astronomical_Twilight     0.100761
# Zipcode                   0.046356
# City                      0.004815
# Street                    0.000070
# Country                   0.000000
# Junction                  0.000000
# Start_Time                0.000000
# End_Time                  0.000000
# Start_Lat                 0.000000
# Turning_Loop              0.000000
# Traffic_Signal            0.000000
# ...

# %%
# TO visualize the missing data of each column
plt.figure(figsize=(20, 5))

df_raw_missing_percentage.plot(kind = "bar", color = "k")
plt.show()

# %% [markdown]
# ###  **Columns considered for the analysis**<br>
# Humidity(%)
# Weather_Condition
# Temperature(F)
# Sunrise_Sunset
# City
# Severity
# Start_Time
# End_Time
# Start_Lat
# Start_Lng
# End_Lat
# End_Lng
# State
# Bump
# Crossing
# Junction

# %%
# Dropping the columns which are not part of our analysis
df = df_raw.drop(['ID',  
        'Distance(mi)', 'Description', 'Number', 'Street',
       'Side',  'County',  'Zipcode', 'Country', 'Timezone',
       'Airport_Code', 'Weather_Timestamp', 'Wind_Chill(F)',
        'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
       'Wind_Speed(mph)', 'Precipitation(in)', 'Amenity',
         'Give_Way',  'No_Exit', 'Railway',
       'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
       'Turning_Loop',  'Civil_Twilight', 'Nautical_Twilight',
       'Astronomical_Twilight'], axis = 1)

# %%
# Know the percentage of misisng values of each column

for col in df:
  print(col, df[col].isnull().sum()/ len(df) *100)
# Out:
# Severity 0.0
# Start_Time 0.0
# End_Time 0.0
# Start_Lat 0.0
# Start_Lng 0.0
# End_Lat 0.0
# End_Lng 0.0
# City 0.0048148869274765565
# State 0.0
# Temperature(F) 2.434645817620518
# Humidity(%) 2.5688300387088794
# Weather_Condition 2.4825135256148467
# Bump 0.0
# Crossing 0.0
# Junction 0.0
# Sunrise_Sunset 0.10076117387646194

# %%
df_missing_percentage = df.isnull().sum().sort_values(ascending = False)/ len(df)*100

# %%
df_missing_percentage
# Out:
# Humidity(%)          2.568830
# Weather_Condition    2.482514
# Temperature(F)       2.434646
# Sunrise_Sunset       0.100761
# City                 0.004815
# Severity             0.000000
# Start_Time           0.000000
# End_Time             0.000000
# Start_Lat            0.000000
# Start_Lng            0.000000
# End_Lat              0.000000
# End_Lng              0.000000
# State                0.000000
# Bump                 0.000000
# Crossing             0.000000
# Junction             0.000000
# dtype: float64

# %%
# To visualize the missing value percentage in each column 
df_missing_percentage.plot(kind= "bar", fontsize = 10, color = 'red')
plt.xlabel("Columns", fontsize = 14)
plt.show()

# %%
# Filled missing values of Temperature column with forward fill method
df["Temperature(F)"].ffill(inplace = True)

# %%
df["Temperature(F)"].isnull().sum()
# Out:
# 0

# %%
# dropping the rows which have null values any any column
df = df.dropna(subset = ["City", "Temperature(F)", "Humidity(%)", "Weather_Condition", "Sunrise_Sunset"])

# %%
# Checking that there is any row having null value
for col in df:
  print(col, df[col].isnull().sum()/ len(df) *100)
# Out:
# Severity 0.0
# Start_Time 0.0
# End_Time 0.0
# Start_Lat 0.0
# Start_Lng 0.0
# End_Lat 0.0
# End_Lng 0.0
# City 0.0
# State 0.0
# Temperature(F) 0.0
# Humidity(%) 0.0
# Weather_Condition 0.0
# Bump 0.0
# Crossing 0.0
# Junction 0.0
# Sunrise_Sunset 0.0

# %%
# Percentage of data we get after data cleaning
len(df)/len(df_raw)*100
# Out:
# 96.90487118947388

# %% [markdown]
# ## **Exploratory Data Analysis and Visualization**

# %% [markdown]
# ### **1.Working on Temperature**

# %% [markdown]
# **Question: How number of accidents related to Temperature of that area?**

# %%
df["Temperature(F)"].mean() # Mean of Temperature
# Out:
# 61.81407411302827

# %%
df["Temperature(F)"].skew() # skewness of temperature column data
# Out:
# -0.4914674344278234

# %%
Accident_with_Temperature = df["Temperature(F)"].value_counts() # Count of accidents according to the temperature

# %%
Accident_with_Temperature
# Out:
#  73.0     64111
#  77.0     63160
#  75.0     60148
#  72.0     59277
#  68.0     58162
#           ...
#  170.6        1
# -12.8         1
# -15.9         1
#  107.2        1
#  99.1         1
# Name: Temperature(F), Length: 781, dtype: int64

# %%
sns.distplot(df["Temperature(F)"])
plt.show()

# %% [markdown]
# ### **Inference**
# -
# Most number of accidents occured when the temperature is in the range 60 F to 90 F
# - Accidents are more frequent in healthy temperature area and count of accidents are less at extreme temperature like less than 20F and more than 100F

# %% [markdown]
# ### **2.Working on Humidity**

# %% [markdown]
# **Question: Check how Humidity is affecting the number of accidents?**

# %%
# Plot showing how accident count is affected by Humidity
sns.histplot(df["Humidity(%)"], bins = 20) 
plt.show()

# %% [markdown]
# ### **Inference**<br>
# As humidity increases Number of accidents also increases, because increase in humidity will increase dehydration which leads to muscle cramps, body fatigue.

# %% [markdown]
# ### **3. Analyze the city column**

# %% [markdown]
# **Question. List the top 20 Cities with highest accident rates an find which city has maximum number of accidents**

# %%
unique_cities = df.City.unique() # Check the unique cities

# %%
# To check number of uniques cities in USA
len(unique_cities)
# Out:
# 10931

# %%
cities_by_accident = df.City.value_counts()  # Count the accidents happened in each city
cities_by_accident
# Out:
# Miami                           105663
# Los Angeles                      68347
# Orlando                          54419
# Dallas                           41821
# Houston                          39152
#                                  ...
# Oglesby                              1
# West Dover                           1
# Gibbsboro                            1
# Krotz Springs                        1
# American Fork-Pleasant Grove         1
# Name: City, Length: 10931, dtype: int64

# %%
# Top 20 cities in accident
cities_by_accident[:20]
# Out:
# Miami           105663
# Los Angeles      68347
# Orlando          54419
# Dallas           41821
# Houston          39152
# Charlotte        33081
# Sacramento       32469
# San Diego        26244
# Raleigh          22800
# Minneapolis      22746
# Portland         20900
# Nashville        20234
# Baton Rouge      18055
# Austin           17215
# Phoenix          16983
# Saint Paul       16691
# New Orleans      15575
# Atlanta          15570
# Jacksonville     14849
# Richmond         13846
# Name: City, dtype: int64

# %%
# Bar graph to show counts of accidents for top 20 cities 
cities_by_accident[:20].plot(kind = "barh")
plt.xlabel("Count of accidents", fontsize = 14)
plt.ylabel("Cities", fontsize = 14)
plt.title("Top 20 cities by most number of  accidents", fontsize = 16)
plt.show()

# %%
# Histogram to see the distribution of accidents over the city
sns.histplot(cities_by_accident,bins = 100)  
plt.show()

# %%
# Cities having more than 1000 accidents
High_accident_cities = cities_by_accident[cities_by_accident >= 1000]

# Cities having less than 1000 accidents
low_accident_cities = cities_by_accident[cities_by_accident < 1000]

# %%
# Number of cities having accidents more than 1000
print("Number of cities having accidents more than 1000: ", len(High_accident_cities))
print("Percentage of accidents per city: ",len(High_accident_cities)/len(unique_cities)*100 )
# Out:
# Number of cities having accidents more than 1000:  472
# Percentage of accidents per city:  4.31799469398957

# %%
# Number of cities having accidents less than 1000
len(low_accident_cities)
# Out:
# 10459

# %%
# Plotting graph for cities having more than 1000 accidents 
sns.histplot(High_accident_cities, bins = 50)
plt.show()

# %% [markdown]
# - Miami city has most number of accidents

# %%
# Plotting graph for cities having less than 1000
sns.histplot(low_accident_cities, log_scale = True)
plt.show()

# %% [markdown]
# Inference from above graph<br>
# - Number of accidents per city for cities having less than 1000 accidents is showing exponential distribution(Positive skewed)
# - So to understand the graph better we can use log scale

# %%
cities_by_accident[cities_by_accident == 1]  # Cities having only 1 accident
# Out:
# Gerry                           1
# Willshire                       1
# Harpersfield                    1
# Pall Mall                       1
# Old Monroe                      1
#                                ..
# Oglesby                         1
# West Dover                      1
# Gibbsboro                       1
# Krotz Springs                   1
# American Fork-Pleasant Grove    1
# Name: City, Length: 917, dtype: int64

# %% [markdown]
# - 917 cities have recorded only 1 accident. So it has to be investigated

# %% [markdown]
# ### **4.State Column**

# %% [markdown]
# **Question: Which State has maximum number of accidents**

# %%
# States present in given data set
df["State"].unique()
# Out:
# array(['OH', 'IN', 'KY', 'WV', 'MI', 'PA', 'CA', 'NV', 'MN', 'TX', 'MO',
#        'CO', 'OK', 'LA', 'KS', 'WI', 'IA', 'MS', 'NE', 'ND', 'WY', 'SD',
#        'MT', 'NM', 'AR', 'IL', 'NJ', 'GA', 'FL', 'NY', 'CT', 'RI', 'SC',
#        'NC', 'MD', 'MA', 'TN', 'VA', 'DE', 'DC', 'ME', 'AL', 'NH', 'VT',
#        'AZ', 'UT', 'ID', 'OR', 'WA'], dtype=object)

# %%
# Total number of columns
df["State"].nunique()
# Out:
# 49

# %%
Accidents_by_States = df.State.value_counts()

# %%
# To visualize the top 20 states with count of accidents
Accidents_by_States[:20].plot(kind = "bar")
plt.xlabel("States", fontsize = 14)
plt.ylabel("Count of Accidents", fontsize = 14)
plt.show()

# %% [markdown]
# ### **Inference**
#
# * California state has highest number of accidents

# %% [markdown]
# ### **5.Working on Start Time**

# %%
# To make date and time more accesible converting that into timestamp
df.Start_Time = pd.to_datetime(df.Start_Time)

# %% [markdown]
# **Working on hours of the day**

# %% [markdown]
# **Question: During which hours of the day maximum accidents occured and what are the hours range that are prone to accidents?**

# %%
# To get the hours of all the accidents
df.Start_Time.dt.hour
# Out:
# 0           0
# 1           5
# 2           6
# 3           6
# 4           7
#            ..
# 2845337    18
# 2845338    19
# 2845339    19
# 2845340    19
# 2845341    18
# Name: Start_Time, Length: 2757275, dtype: int64

# %%
# Plot to see accident counts with corresponding hour
sns.histplot(df.Start_Time.dt.hour, bins = 24) 
plt.xlabel("Start_Time", fontsize = 14)
plt.ylabel("Count of accidents", fontsize = 14)
plt.title("Number of accidents with Timing", fontsize = 16)
plt.show()

# %%
# Get the above  in terms of percentages
sns.distplot(df.Start_Time.dt.hour, bins = 24, kde = True, norm_hist = True)
plt.show()

# %% [markdown]
# ### **Inference**
# - Here we can see 2 trends
# * At 3pm maximum number of accidents occured
# - 1st trend is  accidents occur between 5 am to 10 am
#  - People are in hurry to start their day which leads to more traffic and increase the chances of accidents. <br>
# - High % of accidents happen between 3pm to 7pm as people tend to move back to home which again creates  more traffic

# %% [markdown]
# **Working on the day of the week**

# %% [markdown]
# **Question: On which day of the week maximum number of accidents occur and what is the trend ?**

# %%
df.Start_Time.dt.dayofweek
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 2845337    4
# 2845338    4
# 2845339    4
# 2845340    4
# 2845341    4
# Name: Start_Time, Length: 2757275, dtype: int64

# %%
# Plot to show accidents for each day of the week
sns.distplot(df.Start_Time.dt.dayofweek, bins = 7, kde = False, norm_hist = True)
plt.show()

# %% [markdown]
# ### **Inference**
# * Maximum number of accidents occur on Friday, beginning of weekend could be the major reason for this.
# * We can see that count of accidents more from monday to till Friday as these days are working days<br>
# * During weekend there are less number of accidents as people like to stay at homes as most of people do not travel

# %% [markdown]
# **Question: Finding whether the accident trend by hour is the same on weekends as on weekdays?**

# %%
Monday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 0  ] # Data related to Monday
sunday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 6  ] # Data related to Sunday

# %%
# To see accident trend on Sunday
sns.distplot(sunday_start_time.dt.hour, bins = 24, norm_hist = True )
plt.show()

# %% [markdown]
# ### **Inference**
# On Sunday we can see that accident count is more at the hours where as Saturday ends and Sunday starts
# - During the day time of sunday, accident counts starts increasing from 10 am to 6pm and then starts dropping
# - On Sunday maximum accidents occur in the range time 2pm to 6 pm

# %%
# To see accident trend on Monday
Monday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek == 0]

# %%
# Plot showing Accident counts on each hour of Monday
sns.distplot(Monday_start_time.dt.hour, bins = 24, norm_hist = True )
plt.show()

# %% [markdown]
# Inference
# - By the above graph we can say that accident on Monday(week day) occurs more from 5am to 10am and from 2pm to 6pm
# - During Sunday and Monday the trend of accident is mostly same in afternoon but there is less number of accidents in Weekends morning comapred week day morning

# %% [markdown]
# ## **Checking the accidents according to  month**

# %% [markdown]
# **Question: Check how the months affecting the number of accidents**

# %%
accidents_by_month = df.Start_Time.dt.month  # Accident count for each month

# %%
# Accident count for each month
sns.distplot(accidents_by_month,bins = 12, kde = False) 
plt.xlabel("Start_Time", fontsize = 14)
plt.ylabel("Count of accidents", fontsize = 14)
plt.show()

# %% [markdown]
# ### **Inference** <br>
# - Here we can see that from September to till December accidents increases and December has more number of accidents as Winter starts in USA

# %% [markdown]
# ### **Check the Accidents according to year**

# %% [markdown]
# **Question. What is the trend of accidents year over year? (increasing / decreasing)?**

# %%
# Year wise data
df_year = df.Start_Time.dt.year.value_counts()

# %%
# Showing the year wise accident trend
sns.lineplot(data = df_year)
plt.xlabel("Year")
plt.ylabel("Number of accidents")
plt.show()

# %% [markdown]
# ### **Inference**
# - From above figure we can understand that there is rapid increase in number of accidents in the year 2021 compared to rest of years, So it has to be investigated from data collection levels as there could be no set up in earlier years to collect the data effectively

# %% [markdown]
# **Question. Which year had the most number of accident cases?**

# %%
# Pie plot to show year wise accident distribution in percentage
df_year.plot(kind = "pie", autopct='%1.1f%%')  
plt.show()

# %% [markdown]
# ### **Inference**
# * Year 2021 has most number of accidents that is 53.30% of overall accidents

# %% [markdown]
# ###**Accidents_2016**

# %% [markdown]
# **Question: Analyse the number of accidents changing as per month of every year**

# %%
accidents_2016 = df[df.Start_Time.dt.year == 2016]

# %%
sns.distplot(accidents_2016.Start_Time.dt.month,bins = 12,  kde = False, color = "k")
plt.xlabel("Start_Time", fontsize = 14)
plt.ylabel("Count of accidents", fontsize = 14)
plt.title("Accidents by time")
plt.show()

# %%
accidents_2016.Start_Time.dt.month.value_counts().plot(kind = "pie", autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### **Inference on Accidents of 2016**<br>
# * In the year 2016 number of accidents gradually increased from  January to December
# - December has highest number of accidents

# %% [markdown]
# ###**Accidents_2017**

# %%
accidents_2017 = df[df.Start_Time.dt.year == 2017]

# %%
sns.distplot(accidents_2017.Start_Time.dt.month,bins = 12, kde = False, norm_hist = True, color ="c")
plt.show()

# %%
# pie plot for easy understanding 
accidents_2017.Start_Time.dt.month.value_counts().plot(kind = "pie", autopct='%1.1f%%')
plt.show()

# %% [markdown]
# **Inference on Accidents of 2017**
# * The trend of increasing accidents from the end of 2016 continued in 2017 and it kept decreasing after June
# * In the year 2017 March month has recorded highest number of accidents

# %% [markdown]
# ### **Accidents_2018**

# %%
Accidents_2018 = df[df.Start_Time.dt.year == 2018]

# %%
sns.distplot(Accidents_2018.Start_Time.dt.month,bins = 12, kde = False, norm_hist = True, color = "m")
plt.show()

# %%
Accidents_2018.Start_Time.dt.month.value_counts().plot(kind = "pie", autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ###**Inference on Accidents of 2018**
# - Number of accidents till June kept decreasing but after June they gradually inceased.
# * December has highest number of accidents

# %% [markdown]
# ###**Accidents_2019**

# %%
Accidents_2019 = df[df.Start_Time.dt.year == 2019]

# %%
sns.distplot(Accidents_2019.Start_Time.dt.month,bins = 12, kde = False, norm_hist = True, color="b")
plt.show()

# %%
Accidents_2019.Start_Time.dt.month.value_counts().plot(kind = "pie", autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ###**Inference on Accidents of 2019**
# - In 2018 last 3 months have higher number of accidents

# %% [markdown]
# ###**Accidents_2020**

# %%
Accidents_2020 = df[df.Start_Time.dt.year == 2020]

# %%
sns.distplot(Accidents_2020.Start_Time.dt.month,bins = 12, kde = False, norm_hist = True, color="r")
plt.show()

# %%
Accidents_2020.Start_Time.dt.month.value_counts().plot(kind = "pie", autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ###**Inference on Accidents of 2020**
# - There are no accidents happened in July and August of 2020 or the data might not be recorded on those months
# -2020 Also has highest number of accidents in end of the year

# %% [markdown]
# ###**Accidents_2021**

# %%
Accidents_2021 = df[df.Start_Time.dt.year == 2021]

# %%
sns.distplot(Accidents_2021.Start_Time.dt.month,bins = 12, kde = False, norm_hist = True, color ="g")
plt.show()

# %%
Accidents_2021.Start_Time.dt.month.value_counts().plot(kind = "pie", autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ####**Inference on Accidents of 2021**
# - This year also has highest number of accidents in December

# %% [markdown]
# ### **6.Working on Start_Longitude and Start_Latitude**

# %% [markdown]
# **Question: Which locations of USA has higher Severity?**

# %%
sns.scatterplot(x = df.Start_Lng, y = df.Start_Lat, size=df.Severity, hue=df.Severity)
plt.xlabel("Start_Longitude", fontsize = 14)
plt.ylabel("Start_Latitude", fontsize = 14)
plt.show()

# %% [markdown]
# ### **Inference**
# - Here we can see that Severity of accident is more in central part of the USA and at Costal area of east USA

# %% [markdown]
# ### **7.Working on Severity column**

# %% [markdown]
# **Question: Which level of Severity occured more in the accidents?**

# %%
# Severity wise accident count
sns.countplot(df.Severity)  
plt.show()

# %% [markdown]
# ### Inference
# - Around 2.5 Million accidents are having Severity level 2 that means. The traffic delay due to the accidents are with moderate(low) duration

# %% [markdown]
# ### **8.Working on Sunrise_Sunset**

# %% [markdown]
# **Question: On What part of day(Day/Night) maximum number of accidents occured?**

# %%
Accidents_Day_Night = df.Sunrise_Sunset

# %%
# Day and Night wise accident count
sns.countplot(Accidents_Day_Night)
plt.show()

# %% [markdown]
# ###**Inference**
# - More number of accidents recorded in Day compared to Night

# %% [markdown]
# ### **9.Working on Weather_Condition**

# %% [markdown]
# **Question: How Weather condition affecting the number of accidents?**

# %%
df.Weather_Condition.unique()          # Types of weather conditions
# Out:
# array(['Light Rain', 'Overcast', 'Mostly Cloudy', 'Snow', 'Light Snow',
#        'Cloudy', 'Scattered Clouds', 'Clear', 'Partly Cloudy',
#        'Light Freezing Drizzle', 'Light Drizzle', 'Haze', 'Rain',
#        'Heavy Rain', 'Fair', 'Drizzle', 'Fog', 'Thunderstorms and Rain',
#        'Patches of Fog', 'Light Thunderstorms and Rain', 'Mist',
#        'Rain Showers', 'Light Rain Showers', 'Heavy Drizzle', 'Smoke',
#        'Light Freezing Fog', 'Light Freezing Rain', 'Blowing Snow',
#        'Heavy Thunderstorms and Rain', 'Heavy Snow', 'Snow Grains',
#        'Squalls', 'Light Fog', 'Shallow Fog', 'Thunderstorm',
#        'Light Ice Pellets', 'Thunder', 'Thunder in the Vicinity',
#        'Fair / Windy', 'Light Rain with Thunder',
#        'Heavy Thunderstorms and Snow', 'Light Snow Showers',
#        'Cloudy / Windy', 'Ice Pellets', 'N/A Precipitation',
#        'Light Thunderstorms and Snow', 'T-Storm', 'Rain / Windy',
# ...

# %%
Top_20_Weather_count = df.Weather_Condition.value_counts().sort_values(ascending = False)[:20]      # Top 20 Weather conditions

# %%
# Percentage of accidents happened during Fair Climate
len(df[df.Weather_Condition == "Fair"])/len(df)*100
# Out:
# 39.88833177684489

# %%
# Plot to show weather wise accident count
Top_20_Weather_count.plot(kind= "bar") 
plt.xlabel("Weather Type", fontsize = 14)
plt.show()

# %% [markdown]
# ### **Inference**
# - Here we can see that most number of accidents occured when weather condition was Fair, So here we can assume that there is no such big impact of weather condition on accidents

# %% [markdown]
# ### **10.Working on Bump**

# %% [markdown]
# **Question: Is there any significance role of Bump in Accidents?**

# %%
df["Bump"].value_counts().plot(kind = "bar") 
plt.show()

# %% [markdown]
# ### **Inference**
# - As we can see that there is no bump near the location of accidents, we can assume that accidents happened when vehicles are moving fast

# %% [markdown]
# ### **11.Working on Junction**

# %% [markdown]
# **Question: Is Junction affecting the number of accidents ?**

# %%
len(df[df.Junction == False])/len(df) * 100    # Percentage of accidents happened whe there is no Junction near by
# Out:
# 89.78781586892856

# %%
df.Junction.value_counts().plot(kind="bar")
plt.show()

# %%
df.Junction.value_counts().plot(kind="pie", autopct =  "%.1f%%")
plt.show()

# %% [markdown]
# ### **Inference**
# - Here we can see that 90% of that accidents happened where there were no junctions present
# - Juction has role in only 10 % of accidents.

# %% [markdown]
# ### **12.Working on Crossing**

# %% [markdown]
# **Question: Does crossing is related to the accidents in any way?**

# %%
len(df[df.Crossing == False]) / len(df) * 100  # Percentage of accidents happened whe there is no Crossing near by
# Out:
# 92.88250174538267

# %%
df.Crossing.value_counts().plot(kind = "bar")
plt.show()

# %%
plt.pie(df.Crossing.value_counts(),autopct = "%.1f%%", labels = ["False", "True"], explode = [0,0.5])
plt.show()

# %% [markdown]
# ### **Inference**
# - From above pir chart we can see that 93 % of accidents happened in such a location where there were no Crossings, by this we can say that crossing not playing such big role in the increasing of accidents.

# %% [markdown]
# #**Summary and Conclusion**

# %% [markdown]
# * 4.3% that is 472 cities out of the over 10931 cities recorded 1000 or more accidents. 10459 cities recorded less than 1000 accidents
# * 8.3% that is 917 cities recorded only 1 accidents during the year, which is not conveniencing data.
# * High percentage of accidents occured between 3 to 5 pm; probably because of high traffic around that time because most people will be finding their way back home from work.
# * On the other hand, the number of accidents in the morning peaks from 5am to 10am and the begins to drop until it start to peak again around 1pm. This can also be inferred from rush hour traffic during those hours in the morning to commute to work
# * The highest number of accidents occured on Friday
# The data proves that accidents rate during week days are relatively steep whilst it drops sharply on weekends
# * The day with the lowest accident occurence is Sunday, this may be attributable to the fact that traffic is very low on sunday and most people tend to stay home with their families
# * During the day time of sunday, accident counts starts increasing from 10 am to 6pm and then starts dropping
# * On Sunday maximum accidents occur in the range time 2pm to 6 pm
# * The data proved that the hourly accident distribution on weekends is different from weekdays. Unlike weekdays, the highest accident occurences on weekends were recorded between the hours of 10 am to 6pm. The highest occurences are recorded at 3pm.
# * The lowest rate of occurences on weekend are from 4am to 9am
# * On the points of monthly occurences, that data shows that the rate of accidents begin to increase in September and reach the highest in December.
#
# * Maximum accidents has impact of Severity level 2, which shows traffic clearance is faster in US.
# * Presence of Bump, Junction and Crossings are not effectively impacting on accidents
# * With the increase in Humidity number of accidents increased and temperature showing no such relation as in fine/regular range of temperature we have higher number of accidents
